# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Project/temporal-shift-module/results/data_e10.npy
# output_list=[epoch,i,loss_val,top1_val,top5_val]

# %%
x = np.load('data_e1.npy')
dataset = pd.DataFrame({'Iteration': x[:, 1]/20, 'Loss': x[:, 2]})
dataset
# Out:
#      Iteration    Loss
# 0          0.0  0.1582
# 1          1.0  0.9337
# 2          2.0  0.0131
# 3          3.0  0.2337
# 4          4.0  0.9953
# 5          5.0  0.9070
# 6          6.0  0.0275
# 7          7.0  0.7890
# 8          8.0  0.9468
# 9          9.0  0.0275
# 10        10.0  0.9180
# 11        11.0  0.9985
# 12        12.0  0.7973
# 13        13.0  0.0343
# 14        14.0  0.0119
# 15        15.0  0.0011
# 16        16.0  0.9088
# 17        17.0  0.8801
# 18        18.0  0.7507
# 19        19.0  0.9261
# 20        20.0  0.8398
# 21        21.0  0.8835
# 22        22.0  0.8755
# 23        23.0  0.7382
# 24        24.0  0.9598
# 25        25.0  0.8820
# 26        26.0  0.9597
# 27        27.0  0.7720
# 28        28.0  0.8925
# 29        29.0  0.9357
# ..         ...     ...
# 102      102.0  0.9007
# 103      103.0  0.4661
# 104      104.0  0.7479
# 105      105.0  0.9075
# 106      106.0  0.6697
# 107      107.0  0.6821
# 108      108.0  0.0622
# 109      109.0  0.7219
# ...

# %%
dataset.plot.line(x='Iteration', y='Loss')

# %%
x10 = np.load('data_e10.npy')
dataset2 = pd.DataFrame({'Iteration': x10[:, 1]/20, 'Loss': x10[:, 2]})
dataset2.head()
# Out:
#    Iteration    Loss
# 0        0.0  0.7164
# 1        1.0  0.0170
# 2        2.0  0.8516
# 3        3.0  0.9377
# 4        4.0  0.4615

# %%
ax = dataset2.plot.line(x='Iteration', y='Loss')
ax.set_xlabel('Iteration')
ax.set_ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.plot(x=dataset2['Iteration'],y=dataset2[''])plt.plot(x=dataset2['Iteration'],y=dataset2[''])
